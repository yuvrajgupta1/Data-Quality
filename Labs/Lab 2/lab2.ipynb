# %% [markdown]
# # Lab 2: Python, Pandas, and Visualizing Data

# %% [markdown]
# In this lab we will go through more examples of working with data in Python and Pandas, and focus on visualizing data.
#
# Answer the lab questions at the very end for your lab assignment.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Enable inline plotting
# %matplotlib inline

# %% [markdown]
# ## Reading in Data
#
# We'll read in a dataset containing some information about cars.
#
# It's in a CSV file.

# %%
Location = 'mtcars.csv'
df = pd.read_csv(Location)

# %% [markdown]
# We can use the head() function of the data frame to look at the first 5 records.

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %% [markdown]
# Similarly, we can use the tail() function to look at the last 5 records.

# %%
df.tail()
# Out:
#              model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %% [markdown]
# ## Changing Values
#
# If we want to set a value in the data frame, we can use the _loc_ attribute:

# %%
df.loc[29, 'cyl'] = 4
df.loc[df.model == 'Lotus Europa', 'cyl'] = 12
df.tail()
# Out:
#              model   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  gear  \
# 27    Lotus Europa  30.4   12   95.1  113  3.77  1.513  16.9   1   1     5
# 28  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1     5
# 29    Ferrari Dino  19.7    4  145.0  175  3.62  2.770  15.5   0   1     5
# 30   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1     5
# 31      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1     4
#
#     carb
# 27     2
# 28     4
# 29     6
# 30     8
# 31     2

# %% [markdown]
# If we want to add a new column, we can use _append_.

# %%
hp_cyl_ratio = df['hp'] / df['cyl']

df.assign(ratio = hp_cyl_ratio)
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 27         Lotus Europa  30.4   12   95.1  113  3.77  1.513  16.90   1   1
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 29         Ferrari Dino  19.7    4  145.0  175  3.62  2.770  15.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
#
#     gear  carb      ratio
# 0      4     4  18.333333
# 1      4     4  18.333333
# 2      4     1  23.250000
# 3      3     1  18.333333
# 4      3     2  21.875000
# 5      3     1  17.500000
# 6      3     4  30.625000
# 7      4     2  15.500000
# 8      4     2  23.750000
# 9      4     4  20.500000
# 10     4     4  20.500000
# 11     3     3  22.500000
# 12     3     3  22.500000
# 13     3     3  22.500000
# 14     3     4  25.625000
# 15     3     4  26.875000
# 16     3     4  28.750000
# 17     4     1  16.500000
# 18     4     2  13.000000
# 19     4     1  16.250000
# 20     3     1  24.250000
# 21     3     2  18.750000
# 22     3     2  18.750000
# 23     3     4  30.625000
# 24     3     2  21.875000
# 25     4     1  16.500000
# 26     5     2  22.750000
# 27     5     2   9.416667
# 28     5     4  33.000000
# 29     5     6  43.750000
# 30     5     8  41.875000
# 31     4     2  27.250000

# %% [markdown]
# # Visualizing Data

# %% [markdown]
# We can plot a histogram showing the distribution of mpg (miles per gallon, or fuel efficiency) for all cars.

# %%
plt.figure()
df['mpg'].plot.hist()
plt.xlabel('Miles per Gallon')
plt.show()

# %% [markdown]
# We can create a boxplot, showing the distribution of mpg based on number of cylinders.

# %%
plt.figure()
df.boxplot(column='mpg', by='cyl', grid=False)
plt.xlabel('Miles per Gallon, by Cylinder')
plt.suptitle("")
plt.title("Boxplot Example")
plt.show()

# %% [markdown]
# A barplot could also be used to compare those two variables for each car.

# %%
plt.figure()
df[['mpg', 'cyl']].plot(kind='bar')
plt.show()

# %% [markdown]
# A scatterplot is useful for seeing a relationship between two variables.

# %%
plt.figure()
df.plot.scatter('hp', 'mpg')
plt.xlabel('horsepower')
plt.ylabel('miles per gallon')
plt.show()

# %% [markdown]
# # Grouping Data
#
# We can group data in various ways. For example, we can group the cars by number of cylinders.

# %%
grouped = df.groupby('cyl')
grouped.mean()
# Out:
#            mpg        disp          hp      drat        wt       qsec  \
# cyl
# 4    25.690909  109.672727   88.272727  4.057273  2.400000  19.010000
# 6    19.750000  189.700000  113.500000  3.580000  3.175000  18.390000
# 8    15.100000  353.100000  209.214286  3.229286  3.999214  16.772143
# 12   30.400000   95.100000  113.000000  3.770000  1.513000  16.900000
#
#            vs        am      gear      carb
# cyl
# 4    0.818182  0.727273  4.090909  1.909091
# 6    0.666667  0.333333  3.666667  3.000000
# 8    0.000000  0.142857  3.285714  3.500000
# 12   1.000000  1.000000  5.000000  2.000000

# %%
plt.figure()
df.hist(column='wt', by='cyl')
plt.show()

# %% [markdown]
# # Lab Assignment
#
# Read in the College data in the file College.csv. Then explore the data and provide an overview of the data by doing the following steps.
#
# * Generate at least two scatter plots from the data.
# * Generate at least one boxplot from the data.
# * Generate at least one histogram from the data.
# * Provide at least one example of grouping the data.

# %% [markdown]
# __Deliverables__: Submit your lab code via Blackboard, either in this Jupyter notebook or in a file lab2.py. In either case, I should be able to run the code with no errors.

# %%
Location = 'College.csv'
df1 = pd.read_csv(Location)

# %%
plt.figure()
df1.plot.scatter('Apps', 'Enroll')
plt.xlabel('Applications')
plt.ylabel('Enrolled')
plt.show()

# %%
plt.figure()
df1.plot.scatter('F.Undergrad', 'P.Undergrad')
plt.xlabel('Full time Undergrad')
plt.ylabel('Part time Undergrad')
plt.show()

# %%
plt.figure()
df1.boxplot(column='Grad.Rate', by='Private', grid=False)
plt.xlabel('Graduation Rate by Private Colleges')
plt.suptitle("")
plt.title("Graduation Rate in Private and Non-Private Colleges")
plt.show()

# %%
plt.figure()
df1['Outstate'].plot.hist()
plt.xlabel('Out of State')
plt.show()

# %%
grouped = df1.groupby('Private')
grouped.mean()
# Out:
#                 Apps       Accept       Enroll  Top10perc  Top25perc  \
# Private
# No       5729.919811  3919.287736  1640.872642  22.834906  52.702830
# Yes      1977.929204  1305.702655   456.945133  29.330973  56.957522
#
#          F.Undergrad  P.Undergrad      Outstate   Room.Board       Books  \
# Private
# No       8571.004717  1978.188679   6813.410377  3748.240566  554.377358
# Yes      1872.168142   433.966372  11801.693805  4586.143363  547.506195
#
#             Personal        PhD   Terminal  S.F.Ratio  perc.alumni  \
# Private
# No       1676.981132  76.834906  82.816038  17.139151    14.358491
# Yes      1214.440708  71.093805  78.534513  12.945487    25.890265
#
#                Expend  Grad.Rate
# Private
# No        7458.316038  56.042453
# Yes      10486.353982  68.998230
